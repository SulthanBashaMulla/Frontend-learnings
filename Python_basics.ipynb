# %% [markdown]
# <a href="https://colab.research.google.com/github/SulthanBashaMulla/Frontend-learnings/blob/main/Python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git config --global user.name "SulthanBashaMulla"
# !git config --global user.email "mullasulthanbasha@gmail.com"

# %%
# !git config --global --list
# Out:
# user.name=SulthanBashaMulla
# user.email=mullasulthanbasha@gmail.com
